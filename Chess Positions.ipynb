# %%
from src.functions import *

# %%
X,y = importImages(n=1)
squares = to64squares(X[0])
plotSquares(squares)
# Out:
# /home/jake/anaconda3/lib/python3.7/site-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-8a1bf480f923> in <module>
#       1 X,y = importImages(n=1)
#       2 squares = to64squares(X[0])
# ----> 3 plotSquares(squares)
#
# ~/dsi/repos/cap2/src/functions.py in plotSquares(squares)
#      61     i,j=0,0
#      62     for ax in axs.flatten():
# ---> 63         ax = io.imshow(squares[i][j])
#      64         j += 1
#      65         if j > 7:
#
# ~/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py in imshow(arr, plugin, **plugin_args)
#     152     if isinstance(arr, str):
#     153         arr = call_plugin('imread', arr, plugin=plugin)
# ...
